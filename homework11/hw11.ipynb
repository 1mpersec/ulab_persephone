# %% [markdown]
# # HW 11 - Fall Semester Review
# ULAB - Physics and Astronomy Division \
# Due **Sunday, February 2nd, 2025 at 11:59pm** on Gradescope
#
# To prepare for next week’s homework, where we’ll explore exoplanets using **pandas**, this assignment will review fundamental Python concepts within the same theme.

# %% [markdown]
# ## 0 Academic Integrity
# Please type the following message in the cell below as a comment. Sign with your name.
#
# ------
# **I certify that I did not use AI tools, such as ChatGPT, to generate or write code for this assignment. All work submitted is my own and reflects my understanding of the material.**
#
# ------

# %%
# I certify that I did not use AI tools, such as ChatGPT, to generate or write code for this assignment. All work submitted is my own and reflects my understanding of the material.
# Persephone Choi

# %% [markdown]
# ## 1 Functions
# **Orbital Periods and Kepler's Third Law** \
# Kepler's Third Law states that the square of the orbital period $T$ (in years) of a planet is proportional to the cube of the semi-major axis $a$ (in astronomical units, AU):
#
# $$
# T^2 = a^3
# $$
#
# Write a **function** that calculates the orbital period $T$ given the semi-major axis $a$. (So, you can assume that $T = \sqrt{a^3}$.)

# %%
# Define function
def orbital_period(a):
    return (a**3)**0.5

# %% [markdown]
# Call your function with the following values:
# * `planet_a` $ = 0.5\,\text{AU}$
# * `planet_b` $ = 1.0\,\text{AU}$
# * `planet_c` $ = 1.5\,\text{AU}$

# %%
planet_a = 0.5
planet_b = 1.0
planet_c = 1.5

print (orbital_period(planet_a))
print (orbital_period(planet_b))
print (orbital_period(planet_c))
# Out:
# 0.3535533905932738
# 1.0
# 1.8371173070873836

# %% [markdown]
# Import `numpy` in the cell below.

# %%
import numpy as np

# %% [markdown]
# How many times do you need to call numpy in a jupyter notebook? Why?

# %%
# Once in the beginning, before you use numpy functions in future cells.
# The notebook is all one long process of code, so it runs in the context of previous cells (not sure how better to explain).

# %% [markdown]
# Rewrite your **function** from above with a `numpy` function.

# %%
def rewritten_orb_period(a):
    return np.sqrt(a**3)

# %% [markdown]
# Import the `time` package in the cell below.

# %%
import time

# %% [markdown]
# Call both of your functions in the cell below with ($a$ = 5). Time how long it takes each of your functions to run. **DO NOT REWRITE THEM!**

# %%
start_1 = time.time() # Begin timer
orbital_period(5)
end_1 = time.time() # End timer

print (end_1 - start_1) # Print the time elapsed in between


start_2 = time.time()
rewritten_orb_period(5)
end_2 = time.time()

print (end_2 - start_2)
# Out:
# 9.417533874511719e-05
# 0.00013399124145507812

# %% [markdown]
# Which function is faster? Why is it faster? What does that tell you about numpy functions?

# %%
# It appears that the regular function is faster, because it calculates the result directly rather than calling on an outside source to perform the calculation.
# Numpy "sends" the input to the numpy function used, then "returns" with the result, which takes an extra step to show the result.

# %% [markdown]
# Define a **list** in the cell below that contains a least 1,000,000 semi-major axis values.

# %%
list_1 = list(range(1,1000001))

# %% [markdown]
# With a **for** loop. Time each of your functions again with this new list.

# %%
start_3 = time.time()
for num in list_1:
    orbital_period(num) # Goes through numbers in list_1 and runs each through function
end_3 = time.time()

print(end_3 - start_3) # Print time elapsed between timer start / end

start_4 = time.time()
for num in list_1:
    rewritten_orb_period(num)
end_4 = time.time()

print(end_4 - start_4)
# Out:
# 0.35770297050476074
# 1.8633990287780762

# %% [markdown]
# Which function is faster? Why is it faster? What does that tell you about numpy functions?

# %%
# Maybe it's the way I am writing the code, but it still appears that the regular version is faster.
# In my for loop, at least, the function calls each number in list_1 and inputs it into the function individually.
# This makes numpy slower for the same reason that a single calculation is slower -- it takes an extra step.

# %% [markdown]
# ## 2 Indexing + Conditionals
#
# You are provided with a list of exoplanet radii (in Earth radii) and their equilibrium temperatures (in Kelvin):
#
# `radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]` \
# `temperatures = [300, 400, 350, 280, 500, 450]`

# %% [markdown]
# Write a loop to filter and print the radii of planets with temperatures below 350 K.

# %%
radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]
temperatures = [300, 400, 350, 280, 500, 450]

for radius, temp in zip(radii,temperatures):
    if temp < 350:
        print(radius)
# Out:
# 1.2
# 2.0

# %% [markdown]
# Use list slicing to extract and print the radii of the first three planets.

# %%
print (radii[:3])
# Out:
# [1.2, 0.8, 1.5]

# %% [markdown]
# Turn the radii and temperatures data into a dictionary.

# %%
radii_and_temp = {
    radius: temp
    for radius, temp in zip(radii, temperatures)
}

print(radii_and_temp)
# Out:
# {1.2: 300, 0.8: 400, 1.5: 350, 2.0: 280, 1.0: 500, 0.6: 450}

# %% [markdown]
# Give each of the planets in your dictionary a name.

# %%
planet_names = ['A', 'B', 'C', 'D', 'E', 'F']

radii_and_temp_named = {} #creating new dictionary template

#use previous dictionary to attribute names to items
for name, (radius, temps) in zip(planet_names, radii_and_temp.items()):
    radii_and_temp_named[name] = {radius, temps}

radii_and_temp = radii_and_temp_named #redefining into old name for simplicity

print(radii_and_temp)
# Out:
# {'A': {1.2, 300}, 'B': {0.8, 400}, 'C': {1.5, 350}, 'D': {280, 2.0}, 'E': {1.0, 500}, 'F': {0.6, 450}}

# %% [markdown]
# Create a new dictionary of planets with radii between 1.0 and 2.0 Earth radii (inclusive).

# %%
filtered_planets = {}

for name, (radius, temp) in radii_and_temp.items():
    if 1.0 <= radius <= 2.0:
        filtered_planets[name] = stats

print(filtered_planets)
# Out:
# {'A': {1.2, 300}, 'C': {1.2, 300}, 'E': {1.2, 300}}

# %% [markdown]
# ## 3 NumPy
# With your 1,000,000 semi-major axes list from Problem 1, convert it to a `numpy` array.

# %%
array_1 = np.array(list_1)

# %% [markdown]
# With `numpy` find the mean, median, minimum and maximum.

# %%
mean_val = np.mean(array_1)
median_val = np.median(array_1)
min_val = np.min(array_1)
max_val = np.max(array_1)

print(f"Mean: {mean_val}, Median: {median_val}, Minimum: {min_val}, Maximum: {max_val}")
# Out:
# Mean: 500000.5, Median: 500000.5, Minimum: 1, Maximum: 1000000

# %% [markdown]
# Google another `numpy` function and apply it to your data. Explain what it does in a comment.

# %%
really_large_number = np.sum(array_1)
# Sums all the elements in array

print(really_large_number)
# Out:
# 500000500000

# %% [markdown]
# Turn the radii and temperatures from Problem 2 into a multi-dimensional array.

# %%
planet_data = np.array([radii, temperatures])

print(planet_data)
# Out:
# [[  1.2   0.8   1.5   2.    1.    0.6]
#  [300.  400.  350.  280.  500.  450. ]]

# %% [markdown]
# Use a for loop to print the value on the second row, third column.

# %%
for i in range(len(planet_data)): # Row
    for j in range(len(planet_data[i])): # Column
        if i == 1 and j == 2: # Define row and column to print
            print (planet_data[i,j])
# Out:
# 350.0

# %% [markdown]
# Use a `numpy` arrive to print the value on the second row, third column.

# %%
# ...? I am not sure what a numpy arrive is

# %% [markdown]
# ## 4 Plotting
# Create a scatter plot of the following semi-major axes (x-axis) vs. orbital periods (y-axis). Label the axes, add a legend and add a title: "Orbital Periods of Exoplanets."
#
# `semi_major_axes = [0.5, 1.0, 2.0, 1.5, 1.2, 0.8]`

# %%
import matplotlib.pyplot as plt

semi_major_axes = np.array([0.5, 1.0, 2.0, 1.5, 1.2, 0.8])
orbital_periods_val = orbital_period(semi_major_axes)

# Making the plot
plt.scatter(semi_major_axes, orbital_periods_val)

# Add labels
plt.xlabel('Semi-Major Axes')
plt.ylabel('Orbital Period')
plt.title('Orbital Periods of Exoplanets')

# Add legend
plt.legend()

plt.show()

# %% [markdown]
# Create a bar plot of planet radii vs. their equilibrium temperatures. Label the axes, add a legend and add a title: "Equilibrium Temperatures vs. Radii."

# %%
radii = np.array([1.2, 0.8, 1.5, 2.0, 1.0, 0.6])
temperatures = np.array([300, 400, 350, 280, 500, 450])

plt.bar(radii,temperatures)

plt.xlabel('Planet Radii')
plt.ylabel('Equilibrium Temperatures')
plt.title('Equilibrium Temperatures vs. Radii')

# I have no idea what the legend would say here

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Put the scatter plot and bar plot on the same figure (horizonatally).

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6))  # 1 row, 2 columns

# Left subplot
axs[0].scatter(semi_major_axes, orbital_periods_val)
axs[0].set_xlabel('Semi-Major Axes')
axs[0].set_ylabel('Orbital Period')
axs[0].set_title('Orbital Periods of Exoplanets')
axs[0].legend()
    
# Right subplot
axs[1].bar(radii,temperatures)
axs[1].set_title('Equilibrium Temperatures vs. Radii')
axs[1].set_xlabel('Planet Radii')
axs[1].set_ylabel('Equilibrium Temperatures')

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## 5 Modules
# Choose a function from this homework and put it into a module. Import the module with the function below. Make sure to show the output.

# %%
import timer as tm

print (tm.orbital_period_timer(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[207], line 3
#       1 import timer as tm
# ----> 3 print (tm.orbital_period_timer(10))
#
# File ~/ULAB/ulab_persephone/homework11/timer.py:2, in orbital_period_timer(a)
#       1 def orbital_period_timer(a):
# ----> 2     start = time.time() # Begin timer
#       3     orbital_period(a)
#       4     end = time.time() # End timer
#
# NameError: name 'time' is not defined
