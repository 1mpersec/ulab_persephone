# %% [markdown]
# # HW 16 - Animation
# ULAB - Physics and Astronomy Division \
# Due **Sunday, March 16th, 2025 at 11:59pm** on Gradescope
#
# **Make sure to work on this notebook in DataHub!**
#
# # 1) Recap of lecture
# **Copy and paste** your code from lecture for the neural network with the **default** settings (i.e. before we improved the model). Make sure to also import the `data.py` file.

# %%
import torch
import data

model = torch.nn.Sequential(
    torch.nn.Linear(2,50),
    torch.nn.Sigmoid(),
    torch.nn.Linear(50,1)
)

loss_fn = torch.nn.MSELoss()

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

for t in range(1000):
    y_pred = model(data.x)
    loss = loss_fn(y_pred, data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if t % 100 ==0:
        print(f"Iteration{t}, Loss:{loss.item()}")
# Out:
# Iteration0, Loss:1.0042259693145752
# Iteration100, Loss:0.9346174597740173
# Iteration200, Loss:0.8043649792671204
# Iteration300, Loss:0.6517367959022522
# Iteration400, Loss:0.5269356966018677
# Iteration500, Loss:0.43229401111602783
# Iteration600, Loss:0.35320332646369934
# Iteration700, Loss:0.2905328869819641
# Iteration800, Loss:0.24202615022659302
# Iteration900, Loss:0.21093136072158813

# %% [markdown]
# What is the difference between artificial intelligence, machine learning and deep learning?

# %%
# AI is the umbrella term for something that mimicks human intelligence
# Machine learning is a type of AI that learn from data and predict answers
# Deep learning is a type of machine learning that uses neural networks which makes predictions based on a model

# %% [markdown]
# What is a neural network?

# %%
# A neural network is a part of deep learning that processes data in several layers and learns patterns

# %% [markdown]
# In lecture, we used `torch.nn.Linear(2, 50)`. What do the numbers `2` and `50` represent?

# %%
# 2 = input size
# 50 = output size

# %% [markdown]
# What does the activation function do?

# %%
# Activtion functions allow the neural networks to use the data to determine a complex pattern

# %% [markdown]
# What is a loss function? Why do we need one?

# %%
# The loss function quantifies the error in the predictions that the model makes
# We need it because we want to know how accurate the model is to optimize it

# %% [markdown]
# Why do we call `optimizer.zero_grad()` before calling `loss.backward()`?

# %%
# loss.backward() resets the previous output so that it doesn't get added in with the new output

# %% [markdown]
# # 2) Modifying the Neural Network
# What line do you need to modify to use **30 neurons** instead of **50**? Don't change anything else. Give the original and then modified line.

# %%
# torch.nn.Linear(2,50) -> torch.nn.Linear(2,30)

# %% [markdown]
# With your default code above, run your model with **30 neurons**. Compare the loss functions from lecture to your modification on the **1000th** iteration.

# %%
model_new = torch.nn.Sequential(
    torch.nn.Linear(2,30),
    torch.nn.Sigmoid(),
    torch.nn.Linear(30,1)
)

loss_fn = torch.nn.MSELoss()

optimizer = torch.optim.Adam(model_new.parameters(), lr=1e-3)

for t in range(1000):
    y_pred = model_new(data.x)
    loss = loss_fn(y_pred, data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if t % 100 ==0:
        print(f"Iteration{t}, Loss:{loss.item()}")

# It's more or less similar, maybe a bit worse
# Out:
# Iteration0, Loss:1.1240583658218384
# Iteration100, Loss:0.9945065975189209
# Iteration200, Loss:0.9748507142066956
# Iteration300, Loss:0.9347223043441772
# Iteration400, Loss:0.8578783273696899
# Iteration500, Loss:0.7424514293670654
# Iteration600, Loss:0.6235761046409607
# Iteration700, Loss:0.5282335877418518
# Iteration800, Loss:0.4599706828594208
# Iteration900, Loss:0.4146588146686554

# %% [markdown]
# Return to **50 neurons**. Change your activation function from `torch.nn.Sigmoid()` to `torch.nn.ReLU`. Compare the loss functions from lecture to your modification on the **1000th** iteration.

# %%
model_relu = torch.nn.Sequential(
    torch.nn.Linear(2,50),
    torch.nn.ReLU(),
    torch.nn.Linear(50,1)
)

loss_fn = torch.nn.MSELoss()

optimizer = torch.optim.Adam(model_relu.parameters(), lr=1e-3)

for t in range(1000):
    y_pred = model_relu(data.x)
    loss = loss_fn(y_pred, data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if t % 100 ==0:
        print(f"Iteration{t}, Loss:{loss.item()}")

# Again similar
# Out:
# Iteration0, Loss:1.6076699495315552
# Iteration100, Loss:0.9601418972015381
# Iteration200, Loss:0.836923360824585
# Iteration300, Loss:0.7186713218688965
# Iteration400, Loss:0.6549580097198486
# Iteration500, Loss:0.6138935089111328
# Iteration600, Loss:0.5642950534820557
# Iteration700, Loss:0.512895405292511
# Iteration800, Loss:0.46944841742515564
# Iteration900, Loss:0.42704135179519653

# %% [markdown]
# Change your activation function from `torch.nn.Sigmoid()` to `torch.nn.Tanh`? Compare the loss functions from lecture to your modification on the **1000th** iteration.

# %%
model_tanh = torch.nn.Sequential(
    torch.nn.Linear(2,50),
    torch.nn.Tanh(),
    torch.nn.Linear(50,1)
)

loss_fn = torch.nn.MSELoss()

optimizer = torch.optim.Adam(model_tanh.parameters(), lr=1e-3)

for t in range(1000):
    y_pred = model_tanh(data.x)
    loss = loss_fn(y_pred, data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if t % 100 ==0:
        print(f"Iteration{t}, Loss:{loss.item()}")

# The end result is a little better
# Out:
# Iteration0, Loss:1.0452076196670532
# Iteration100, Loss:0.7278062701225281
# Iteration200, Loss:0.4672224819660187
# Iteration300, Loss:0.35231876373291016
# Iteration400, Loss:0.288347989320755
# Iteration500, Loss:0.2520003616809845
# Iteration600, Loss:0.22631628811359406
# Iteration700, Loss:0.20594003796577454
# Iteration800, Loss:0.18818332254886627
# Iteration900, Loss:0.17236410081386566

# %% [markdown]
# What is the difference between `torch.nn.Sigmoid()`, `torch.nn.ReLU` and `torch.nn.Tanh`?

# %%
# I think they use different functions to make predictions, and some functions are a better fit for the data than others.

# %% [markdown]
# Return to `torch.nn.Sigmoid()`. Change your learning rate from `1e-3` to `1e-2` in your optimizer. Compare the loss functions from lecture to your modification on the **1000th** iteration.

# %%
model_e = torch.nn.Sequential(
    torch.nn.Linear(2,50),
    torch.nn.Sigmoid(),
    torch.nn.Linear(50,1)
)

loss_fn = torch.nn.MSELoss()

optimizer = torch.optim.Adam(model_e.parameters(), lr=1e-2)

for t in range(1000):
    y_pred = model_e(data.x)
    loss = loss_fn(y_pred, data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if t % 100 ==0:
        print(f"Iteration{t}, Loss:{loss.item()}")

# Loss looks a lot better, decreased by one oom
# Out:
# Iteration0, Loss:1.2395435571670532
# Iteration100, Loss:0.4865677058696747
# Iteration200, Loss:0.3366904854774475
# Iteration300, Loss:0.24454407393932343
# Iteration400, Loss:0.16597111523151398
# Iteration500, Loss:0.1270843744277954
# Iteration600, Loss:0.10425488650798798
# Iteration700, Loss:0.09297608584165573
# Iteration800, Loss:0.08211729675531387
# Iteration900, Loss:0.07684958726167679

# %% [markdown]
# Modify your model to have **two hidden layers** instead of one. Give that code here.

# %%
model_two = torch.nn.Sequential(
    torch.nn.Linear(2,30),
    torch.nn.Sigmoid(),
    torch.nn.Linear(30,50),
    torch.nn.Sigmoid(),
    torch.nn.Linear(50,1)
)

loss_fn = torch.nn.MSELoss()

optimizer = torch.optim.Adam(model_two.parameters(), lr=1e-3)

for t in range(1000):
    y_pred = model_two(data.x)
    loss = loss_fn(y_pred, data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if t % 100 ==0:
        print(f"Iteration{t}, Loss:{loss.item()}")

# Not the best not the worst
# Out:
# Iteration0, Loss:1.0813860893249512
# Iteration100, Loss:0.9920912981033325
# Iteration200, Loss:0.9576285481452942
# Iteration300, Loss:0.804036021232605
# Iteration400, Loss:0.4936866760253906
# Iteration500, Loss:0.38211652636528015
# Iteration600, Loss:0.3502982258796692
# Iteration700, Loss:0.3211826980113983
# Iteration800, Loss:0.2642046809196472
# Iteration900, Loss:0.21948087215423584

# %% [markdown]
# # 3) More Advanced
# Create a new file called `new_data.py`, make a new "hidden" function and add noise/ obscure the data (e.g. like what is done in `data.py` from lecture). Import that file here.

# %%
import new_data

# %% [markdown]
# Define a new model and train it **poorly** in the cell below.

# %%
bad_model = torch.nn.Sequential(
    torch.nn.Linear(2,10),
    torch.nn.Sigmoid(),
    torch.nn.Linear(10,1)
)

loss_fn = torch.nn.MSELoss()

optimizer = torch.optim.Adam(bad_model.parameters(), lr=1e-2)

for t in range(100):
    y_pred = bad_model(new_data.x)
    loss = loss_fn(y_pred, new_data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if t % 10 ==0:
        print(f"Iteration{t}, Loss:{loss.item()}")
# Out:
# Iteration0, Loss:1.8409725427627563
# Iteration10, Loss:0.8612496852874756
# Iteration20, Loss:0.637687623500824
# Iteration30, Loss:0.6615499258041382
# Iteration40, Loss:0.641344428062439
# Iteration50, Loss:0.6292739510536194
# Iteration60, Loss:0.626100480556488
# Iteration70, Loss:0.6189342737197876
# Iteration80, Loss:0.610271692276001
# Iteration90, Loss:0.5989891886711121

# %% [markdown]
# Improve your model and train it **well** in the cell below. (You can add more neurons, iterations, etc).

# %%
better_model = torch.nn.Sequential(
    torch.nn.Linear(2,30),
    torch.nn.Sigmoid(),
    torch.nn.Linear(30,50),
    torch.nn.Tanh(),
    torch.nn.Linear(50,100),
    torch.nn.ReLU(),
    torch.nn.Linear(100,1)
)

loss_fn = torch.nn.MSELoss()

optimizer = torch.optim.Adam(better_model.parameters(), lr=1e-3)

for t in range(5000):
    y_pred = better_model(new_data.x)
    loss = loss_fn(y_pred, new_data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if t % 500 ==0:
        print(f"Iteration{t}, Loss:{loss.item()}")
# Out:
# Iteration0, Loss:1.047967553138733
# Iteration500, Loss:0.15027451515197754
# Iteration1000, Loss:0.12791851162910461
# Iteration1500, Loss:0.11581074446439743
# Iteration2000, Loss:0.07063224166631699
# Iteration2500, Loss:0.04744599014520645
# Iteration3000, Loss:0.03647981584072113
# Iteration3500, Loss:0.024648426100611687
# Iteration4000, Loss:0.02065572515130043
# Iteration4500, Loss:0.018029330298304558

# %% [markdown]
# Make foure subplots (two rows, two columns).
# - (TOP LEFT) Show what the "hidden pattern" is supposed to be.
# - (TOP RIGHT) Show that your "data" is.
# - (BOTTOM LEFT) Show your model's prediction when you trained it poorly.
# - (BOTTOM RIGHT) Show your model's prediction when you trained it well.

# %%
import numpy as np
import matplotlib.pyplot as plt

new_x = torch.linspace(-10,10,100)
grid = torch.stack(torch.meshgrid((new_x, new_x)), dim=2)

bad_output = bad_model(grid).detach()
better_output = better_model(grid).detach()

fig, axs = plt.subplots(2, 2, figsize=(10, 8))

axs[0, 1].scatter(new_data.x_values, new_data.y_values)
axs[0, 1].set_title("Real Data")

axs[0, 0].imshow(new_data.pattern)
axs[0, 0].set_title("Real Pattern")

axs[1, 0].imshow(bad_output, extent=(-10,10,-10,10))
axs[1, 0].set_title("Poor Training")

axs[1, 1].imshow(better_output, extent=(-10,10,-10,10))
axs[1, 1].set_title("Better Training")
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3550.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Text(0.5, 1.0, 'Better Training')

# %% [markdown]
# # 4) Challenge
# Find some data online and build a neural network around it. Make sure to also answer these questions:
# - Where did you find your data?
# - How well does your model match your data?

# %%
import swedish_insurance as si
import torch
import numpy as np


model_si = torch.nn.Sequential(
    torch.nn.Linear(1,30),
    torch.nn.ReLU(),
    torch.nn.Linear(30,63),
    torch.nn.Sigmoid(),
    torch.nn.Linear(63,1)
)

# Using both semi-linearly shaped fits for linear regression

loss_fn = torch.nn.MSELoss()

optimizer = torch.optim.Adam(model_si.parameters(), lr=1e-2)

for t in range(1000):
    y_pred = model_si(si.x_vals).T
    loss = loss_fn(y_pred, si.y_vals)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if t % 100 ==0:
        print(f"Iteration{t}, Loss:{loss.item()}")

# It appears that because the data is technically linear, the fit can only be so good
# Changing parameters, learning rate, adding and subtracting layers, etc. all plateau the loss at around 7499
# Out:
# Iteration0, Loss:17286.1953125
# Iteration100, Loss:9444.64453125
# Iteration200, Loss:7584.51953125
# Iteration300, Loss:7499.79541015625
# Iteration400, Loss:7499.017578125
# Iteration500, Loss:7499.0166015625
# Iteration600, Loss:7499.0166015625
# Iteration700, Loss:7499.01611328125
# Iteration800, Loss:7499.0166015625
# Iteration900, Loss:7499.01611328125

# %% [markdown]
# Once you are done, make sure to:
# - Download this notebook and all releveant files (`new_data.py`, stuff from question 4, etc) from datahub.
# - Move it to your **remote repository**.
# - Upload to Gradescope!
