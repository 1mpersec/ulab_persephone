# %% [markdown]
# # HW 16 - Animation
# ULAB - Physics and Astronomy Division \
# Due **Sunday, March 16th, 2025 at 11:59pm** on Gradescope
#
# **Make sure to work on this notebook in DataHub!**
#
# # 1) Recap of lecture
# **Copy and paste** your code from lecture for the neural network with the **default** settings (i.e. before we improved the model). Make sure to also import the `data.py` file.

# %%
import torch
import data

model = torch.nn.Sequential(
    torch.nn.Linear(2,50),
    torch.nn.Sigmoid(),
    torch.nn.Linear(50,1)
)

loss_fn = torch.nn.MSELoss()

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

for t in range(1000):
    y_pred = model(data.x)
    loss = loss_fn(y_pred, data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if t % 100 ==0:
        print(f"Iteration{t}, Loss:{loss.item()}")
# Out:
# Iteration0, Loss:1.0774649381637573
# Iteration100, Loss:0.9878495335578918
# Iteration200, Loss:0.898286759853363
# Iteration300, Loss:0.7671352624893188
# Iteration400, Loss:0.6343668699264526
# Iteration500, Loss:0.5240960121154785
# Iteration600, Loss:0.4328611195087433
# Iteration700, Loss:0.3595191538333893
# Iteration800, Loss:0.30812695622444153
# Iteration900, Loss:0.2713299095630646

# %% [markdown]
# What is the difference between artificial intelligence, machine learning and deep learning?

# %%
# AI is the umbrella term for something that mimicks human intelligence
# Machine learning is a type of AI that learn from data and predict answers
# Deep learning is a type of machine learning that uses neural networks which makes predictions based on a model

# %% [markdown]
# What is a neural network?

# %%
# A neural network is a part of deep learning that processes data in several layers and learns patterns

# %% [markdown]
# In lecture, we used `torch.nn.Linear(2, 50)`. What do the numbers `2` and `50` represent?

# %%
# 2 = input size
# 50 = output size

# %% [markdown]
# What does the activation function do?

# %%
# Activtion functions allow the neural networks to use the data to determine a complex pattern

# %% [markdown]
# What is a loss function? Why do we need one?

# %%
# The loss function quantifies the error in the predictions that the model makes
# We need it because we want to know how accurate the model is to optimize it

# %% [markdown]
# Why do we call `optimizer.zero_grad()` before calling `loss.backward()`?

# %%
# loss.backward() resets the previous output so that it doesn't get added in with the new output

# %% [markdown]
# # 2) Modifying the Neural Network
# What line do you need to modify to use **30 neurons** instead of **50**? Don't change anything else. Give the original and then modified line.

# %%
# torch.nn.Linear(2,50) -> torch.nn.Linear(2,30)

# %% [markdown]
# With your default code above, run your model with **30 neurons**. Compare the loss functions from lecture to your modification on the **1000th** iteration.

# %%
model_new = torch.nn.Sequential(
    torch.nn.Linear(2,30),
    torch.nn.Sigmoid(),
    torch.nn.Linear(50,1)
)

loss_fn = torch.nn.MSELoss()

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

for t in range(1000):
    y_pred = model(data.x)
    loss = loss_fn(y_pred, data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if t % 100 ==0:
        print(f"Iteration{t}, Loss:{loss.item()}")

# The loss function is much smaller than when there were 50
# Out:
# Iteration0, Loss:0.24564573168754578
# Iteration100, Loss:0.22274062037467957
# Iteration200, Loss:0.20605425536632538
# Iteration300, Loss:0.19097191095352173
# Iteration400, Loss:0.17731903493404388
# Iteration500, Loss:0.1662731170654297
# Iteration600, Loss:0.1545369029045105
# Iteration700, Loss:0.14556895196437836
# Iteration800, Loss:0.13676737248897552
# Iteration900, Loss:0.12727577984333038

# %% [markdown]
# Return to **50 neurons**. Change your activation function from `torch.nn.Sigmoid()` to `torch.nn.ReLU`. Compare the loss functions from lecture to your modification on the **1000th** iteration.

# %%
model_new = torch.nn.Sequential(
    torch.nn.Linear(2,50),
    torch.nn.ReLU(),
    torch.nn.Linear(50,1)
)

loss_fn = torch.nn.MSELoss()

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

for t in range(1000):
    y_pred = model(data.x)
    loss = loss_fn(y_pred, data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if t % 100 ==0:
        print(f"Iteration{t}, Loss:{loss.item()}")

# The loss function significantly decreased from when we used torch.nn.Sigmoid, for both the 30 and 50 neuron network cases
# Out:
# Iteration0, Loss:0.11910160630941391
# Iteration100, Loss:0.11448274552822113
# Iteration200, Loss:0.10964319109916687
# Iteration300, Loss:0.10524094849824905
# Iteration400, Loss:0.10122623294591904
# Iteration500, Loss:0.09708883613348007
# Iteration600, Loss:0.08949415385723114
# Iteration700, Loss:0.08300616592168808
# Iteration800, Loss:0.07810122519731522
# Iteration900, Loss:0.07398064434528351

# %% [markdown]
# Change your activation function from `torch.nn.Sigmoid()` to `torch.nn.Tanh`? Compare the loss functions from lecture to your modification on the **1000th** iteration.

# %%
model_new = torch.nn.Sequential(
    torch.nn.Linear(2,50),
    torch.nn.Tanh(),
    torch.nn.Linear(50,1)
)

loss_fn = torch.nn.MSELoss()

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

for t in range(1000):
    y_pred = model(data.x)
    loss = loss_fn(y_pred, data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if t % 100 ==0:
        print(f"Iteration{t}, Loss:{loss.item()}")

# The loss function decreased even more!
# Out:
# Iteration0, Loss:0.07032299041748047
# Iteration100, Loss:0.06826398521661758
# Iteration200, Loss:0.06570271402597427
# Iteration300, Loss:0.06300696730613708
# Iteration400, Loss:0.06019171327352524
# Iteration500, Loss:0.056252095848321915
# Iteration600, Loss:0.05068263038992882
# Iteration700, Loss:0.04705095663666725
# Iteration800, Loss:0.0429084338247776
# Iteration900, Loss:0.040489211678504944

# %% [markdown]
# What is the difference between `torch.nn.Sigmoid()`, `torch.nn.ReLU` and `torch.nn.Tanh`?

# %%
# I think they use different functions to make predictions, and some functions are a better fit for the data than others.

# %% [markdown]
# Return to `torch.nn.Sigmoid()`. Change your learning rate from `1e-3` to `1e-2` in your optimizer. Compare the loss functions from lecture to your modification on the **1000th** iteration.

# %%
model_new = torch.nn.Sequential(
    torch.nn.Linear(2,50),
    torch.nn.Sigmoid(),
    torch.nn.Linear(50,1)
)

loss_fn = torch.nn.MSELoss()

optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)

for t in range(1000):
    y_pred = model(data.x)
    loss = loss_fn(y_pred, data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if t % 100 ==0:
        print(f"Iteration{t}, Loss:{loss.item()}")

# This one has an even smaller loss function, so it must be making the closest predictions
# Out:
# Iteration0, Loss:0.03687099739909172
# Iteration100, Loss:0.03582499176263809
# Iteration200, Loss:0.03457503765821457
# Iteration300, Loss:0.03316902741789818
# Iteration400, Loss:0.031597305089235306
# Iteration500, Loss:0.02974397875368595
# Iteration600, Loss:0.028104646131396294
# Iteration700, Loss:0.026877092197537422
# Iteration800, Loss:0.025804689154028893
# Iteration900, Loss:0.024674072861671448

# %% [markdown]
# Modify your model to have **two hidden layers** instead of one. Give that code here.

# %%
model_new = torch.nn.Sequential(
    torch.nn.Linear(2,30),
    torch.nn.Sigmoid(),
    torch.nn.Linear(30,50),
    torch.nn.Sigmoid(),
    torch.nn.Linear(50,1)
)

loss_fn = torch.nn.MSELoss()

optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)

for t in range(1000):
    y_pred = model(data.x)
    loss = loss_fn(y_pred, data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if t % 100 ==0:
        print(f"Iteration{t}, Loss:{loss.item()}")

# The predictions seem to continually get better as we train it in different ways
# Out:
# Iteration0, Loss:0.02233215421438217
# Iteration100, Loss:0.021738924086093903
# Iteration200, Loss:0.021129688248038292
# Iteration300, Loss:0.02042570151388645
# Iteration400, Loss:0.019685011357069016
# Iteration500, Loss:0.0189407616853714
# Iteration600, Loss:0.018406009301543236
# Iteration700, Loss:0.01760508492588997
# Iteration800, Loss:0.016941417008638382
# Iteration900, Loss:0.016349678859114647

# %% [markdown]
# # 3) More Advanced
# Create a new file called `new_data.py`, make a new "hidden" function and add noise/ obscure the data (e.g. like what is done in `data.py` from lecture). Import that file here.

# %%
import new_data

# %% [markdown]
# Define a new model and train it **poorly** in the cell below.

# %%
bad_model = torch.nn.Sequential(
    torch.nn.Linear(2,10),
    torch.nn.Sigmoid(),
    torch.nn.Linear(10,1)
)

loss_fn = torch.nn.MSELoss()

optimizer = torch.optim.Adam(model.parameters(), lr=1)

for t in range(100):
    y_pred = model(new_data.x)
    loss = loss_fn(y_pred, new_data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if t % 10 ==0:
        print(f"Iteration{t}, Loss:{loss.item()}")
# Out:
# Iteration0, Loss:0.016930464655160904
# Iteration10, Loss:9.398092269897461
# Iteration20, Loss:5.613324165344238
# Iteration30, Loss:2.828873634338379
# Iteration40, Loss:1.6253858804702759
# Iteration50, Loss:0.7307354807853699
# Iteration60, Loss:0.49154993891716003
# Iteration70, Loss:0.36780858039855957
# Iteration80, Loss:0.2723332345485687
# Iteration90, Loss:0.20975470542907715

# %% [markdown]
# Improve your model and train it **well** in the cell below. (You can add more neurons, iterations, etc).

# %%
better_model = torch.nn.Sequential(
    torch.nn.Linear(2,30),
    torch.nn.Sigmoid(),
    torch.nn.Linear(30,50),
    torch.nn.Tanh(),
    torch.nn.Linear(50,100),
    torch.nn.ReLU(),
    torch.nn.Linear(100,1)
)

loss_fn = torch.nn.MSELoss()

optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)

for t in range(5000):
    y_pred = model(new_data.x)
    loss = loss_fn(y_pred, new_data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if t % 500 ==0:
        print(f"Iteration{t}, Loss:{loss.item()}")
# Out:
# Iteration0, Loss:0.012513683177530766
# Iteration500, Loss:0.012447791174054146
# Iteration1000, Loss:0.012374763377010822
# Iteration1500, Loss:0.012308560311794281
# Iteration2000, Loss:0.01225628238171339
# Iteration2500, Loss:0.012130514718592167
# Iteration3000, Loss:0.012010224163532257
# Iteration3500, Loss:0.01173851452767849
# Iteration4000, Loss:0.011654812842607498
# Iteration4500, Loss:0.011588910594582558

# %% [markdown]
# Make foure subplots (two rows, two columns).
# - (TOP LEFT) Show what the "hidden pattern" is supposed to be.
# - (TOP RIGHT) Show that your "data" is.
# - (BOTTOM LEFT) Show your model's prediction when you trained it poorly.
# - (BOTTOM RIGHT) Show your model's prediction when you trained it well.

# %%
import numpy as np
import matplotlib.pyplot as plt

new_x = torch.linspace(-0.5 * np.pi, 3 * np.pi, 500)
grid = torch.stack(torch.meshgrid((new_x, new_x)), dim=2)

#real_output = new_data.y(grid).detach()
bad_output = bad_model(grid).detach()
better_output = better_model(grid).detach()

fig, axs = plt.subplots(2, 2, figsize=(10, 8))

axs[0, 0].plot(new_data.x, new_data.y)
axs[0, 0].set_title("Real Pattern")
axs[0, 0].legend()

#axs[0, 1].imshow(real_output, extent=(-10,10,-10,10))
#axs[0, 1].set_title("Real Data")
#axs[0, 1].legend()

axs[1, 0].imshow(bad_output, extent=(-10,10,-10,10))
axs[1, 0].set_title("Poor Training")
axs[1, 0].legend()

axs[1, 1].imshow(better_output, extent=(-10,10,-10,10))
axs[1, 1].set_title("Better Training")
axs[1, 1].legend()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 4 new_x = torch.linspace(-0.5 * np.pi, 3 * np.pi, 500)
#       5 grid = torch.stack(torch.meshgrid((new_x, new_x)), dim=2)
#       7 #real_output = new_data.y(grid).detach()
#
# NameError: name 'torch' is not defined

# %% [markdown]
# # 4) Challenge
# Find some data online and build a neural network around it. Make sure to also answer these questions:
# - Where did you find your data?
# - How well does your model match your data?

# %%
# Your code here

# %% [markdown]
# Once you are done, make sure to:
# - Download this notebook and all releveant files (`new_data.py`, stuff from question 4, etc) from datahub.
# - Move it to your **remote repository**.
# - Upload to Gradescope!
